# %% [markdown]
# ![Databricks Academy](https://files.training.databricks.com/binder/prod_main/build-data-pipelines-with-apache-spark-declarative-pipelines-en_us-3.2.1/images/20260902T093127Z/Build Data Pipelines with Apache Spark Declarative Pipelines/Includes/images/icons/databricks_academy.png)

# %% [markdown]
# # Lecture - Simplified Pipeline Development and Common Pipeline Settings
#
# ## Overview
#
# In this lecture, you will learn how the multi-file editor simplifies pipeline development and debugging and how common pipeline settings customize pipeline execution.
#
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
#
# - **Identify** and configure pipeline settings such as compute, data assets, trigger modes, and advanced options
# - **Develop** a functional Declarative Pipeline using the new pipeline editor and SQL-based syntax for the pipeline

# %% [markdown]
# ## A. Simplified Pipeline Development

# %% [markdown]
# ### A1. What Is the Multi-File Editor?
#
# The multi-file editor in Apache Spark™ Declarative Pipelines makes developing and debugging your ETL pipelines easier and more efficient.
#
# Instead of managing one large file, your pipeline is organized as a set of files visible in the pipeline assets browser, letting you edit code and configure your pipeline components all in one place.
#
#
# <div style="border-left: 4px solid #1976d2; background: #e3f2fd; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
# <div style="display: flex; align-items: flex-start; gap: 12px;">
# <div>
# <strong style="color: #0d47a1; font-size: 1.1em;">Announced at Data & AI Summit 2025</strong>
# <p style="margin: 8px 0 0 0; color: #333;">Write pipeline code using <strong>.sql</strong> or <strong>.py</strong> files (recommended), or use notebooks — your choice. These features help you build robust pipelines faster, streamline your development workflow, debug with integrated tools, and validate without full runs.</p>
# </div>
# </div>
# </div>

# %% [markdown]
# ### A2. Key Features of the Multi-File Editor
#
# The multi-file editor in Apache Spark™ Declarative Pipelines makes developing and debugging your ETL pipelines easier and more efficient.
#
# Instead of managing one large file, your pipeline is organized as a set of files visible in the pipeline assets browser, letting you edit code and configure your pipeline components all in one place.
#
#
# #####Click each number to reveal the key features of the Multi-File Editor.
# <br>
#
# <div style="max-width: 1120px; margin: 0 auto; font-family: system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#
# <style>
#   .hotspot-root {
#     position: relative;
#     max-width: 100%;
#   }
#   .hotspot-wrap {
#     position: relative;
#     display: inline-block;
#     max-width: 100%;
#   }
#   .hotspot-img {
#     width: 1100px;
#     max-width: 100%;
#     height: auto;
#     border-radius: 4px;
#     border: 1px solid #d0d7dd;
#     display: block;
#   }
#   /* Transparent, clickable overlays positioned over the numbers already
#      baked into the screenshot. Centered on each number via translate(). */
#   .hotspot-dot {
#     position: absolute;
#     transform: translate(-50%, -50%);
#     width: 40px;
#     height: 40px;
#     border-radius: 999px;
#     background: transparent;
#     color: transparent;
#     font-size: 0;
#     cursor: pointer;
#     border: 2px solid transparent;
#     transition: box-shadow 0.15s, border-color 0.15s;
#   }
#   .hotspot-dot:hover {
#     border-color: rgba(27,81,98,0.9);
#     box-shadow: 0 0 0 4px rgba(27,81,98,0.18);
#   }
#
#   .hotspot-panel {
#     margin-top: 16px;
#     padding: 14px 16px 12px 16px;
#     border-radius: 10px;
#     border: 1px solid #d0d7dd;
#     background: #F9F7F4;
#     box-shadow: 0 2px 6px rgba(15,23,42,0.06);
#     font-size: 13px;
#     color: #0B2026;
#     display: none;
#   }
#   .hotspot-panel-title {
#     font-size: 15px;
#     font-weight: 700;
#     color: #1B3139;
#     margin-bottom: 6px;
#   }
#   .hotspot-panel-body {
#     line-height: 1.6;
#   }
#   .hotspot-panel-footer {
#     margin-top: 8px;
#     font-size: 11px;
#     color: #64748b;
#     font-style: italic;
#   }
#
#   /* hide radios */
#   .hotspot-radio {
#     display: none;
#   }
#
#   /* active state styling via :checked */
#   #hs1:checked ~ .hotspot-wrap label[for="hs1"],
#   #hs2:checked ~ .hotspot-wrap label[for="hs2"],
#   #hs3:checked ~ .hotspot-wrap label[for="hs3"],
#   #hs4:checked ~ .hotspot-wrap label[for="hs4"],
#   #hs5:checked ~ .hotspot-wrap label[for="hs5"],
#   #hs6:checked ~ .hotspot-wrap label[for="hs6"] {
#     border-color: #1B5162;
#     box-shadow: 0 0 0 4px rgba(27,81,98,0.25);
#   }
#
#   #hs1:checked ~ .hotspot-panels .panel1 { display: block; }
#   #hs2:checked ~ .hotspot-panels .panel2 { display: block; }
#   #hs3:checked ~ .hotspot-panels .panel3 { display: block; }
#   #hs4:checked ~ .hotspot-panels .panel4 { display: block; }
#   #hs5:checked ~ .hotspot-panels .panel5 { display: block; }
#   #hs6:checked ~ .hotspot-panels .panel6 { display: block; }
# </style>
# <div class="hotspot-root">
#   <!-- Radios to drive state -->
#   <input type="radio" name="hs" id="hs1" class="hotspot-radio" checked>
#   <input type="radio" name="hs" id="hs2" class="hotspot-radio">
#   <input type="radio" name="hs" id="hs3" class="hotspot-radio">
#   <input type="radio" name="hs" id="hs4" class="hotspot-radio">
#   <input type="radio" name="hs" id="hs5" class="hotspot-radio">
#   <input type="radio" name="hs" id="hs6" class="hotspot-radio">
#   <!-- Image with hotspots -->
#   <div class="hotspot-wrap">
#     <img
#       src="https://files.training.databricks.com/binder/prod_main/build-data-pipelines-with-apache-spark-declarative-pipelines-en_us-3.2.1/images/20260902T093127Z/Build Data Pipelines with Apache Spark Declarative Pipelines/Includes/images/lecture_simplified_pipeline_development/key_features.png"
#       alt="Pipeline key features"
#       class="hotspot-img">
#     <!-- Approximate positions (adjust top/left as needed) -->
#     <label class="hotspot-dot" for="hs1" style="top: 25.5%; left: 13.3%;">1</label>
#     <label class="hotspot-dot" for="hs2" style="top: 7.8%; left: 31.6%;">2</label>
#     <label class="hotspot-dot" for="hs3" style="top: 13.7%; left: 50.0%;">3</label>
#     <label class="hotspot-dot" for="hs4" style="top: 25.5%; left: 64.0%;">4</label>
#     <label class="hotspot-dot" for="hs5" style="top: 79.3%; left: 19.4%;">5</label>
#     <label class="hotspot-dot" for="hs6" style="top: 73.2%; left: 76.3%;">6</label>
#   </div>
#   <!-- Panels driven by radios -->
#   <div class="hotspot-panels">
#     <div class="hotspot-panel panel1">
#       <div class="hotspot-panel-title">Pipeline Asset Browser</div>
#       <div class="hotspot-panel-body">To easily navigate pipeline files</div>
#     </div>
#     <div class="hotspot-panel panel2">
#       <div class="hotspot-panel-title">Multi-File Code Editor</div>
#       <div class="hotspot-panel-body">Designed for step-by-step pipeline development</div>
#     </div>
#     <div class="hotspot-panel panel3">
#       <div class="hotspot-panel-title">Pipeline-Specific Toolbars</div>
#       <div class="hotspot-panel-body">For quick access to common actions</div>
#     </div>
#     <div class="hotspot-panel panel4">
#       <div class="hotspot-panel-title">Interactive DAG</div>
#       <div class="hotspot-panel-body">(Directed Acyclic Graph) for visualizing pipeline dependencies</div>
#     </div>
#     <div class="hotspot-panel panel5">
#       <div class="hotspot-panel-title">Data Previews</div>
#       <div class="hotspot-panel-body">To inspect intermediate results
# </div>
#     </div>
#     <div class="hotspot-panel panel6">
#       <div class="hotspot-panel-title">Execution Insights, Debugging &amp; Dry Run</div>
#       <div class="hotspot-panel-body">To monitor pipeline runs
#       <ul>
#       <li>Easier debugging with integrated tools
#       <li>Faster validation through dry run capabilities, so you can check your pipeline without running full executions
#       </li>
#       </ul>
# </div>
#     </div>
#   </div>
# </div>
# </div>

# %% [markdown]
# #####Documentation
#
#
# <a href="https://docs.databricks.com/aws/en/dlt/dlt-multi-file-editor" style="color: #1976d2; text-decoration: underline;">Develop and debug ETL pipelines with the multi-file editor in Apache Spark™ Declarative Pipelines</a>

# %% [markdown]
# ## B. Common Pipeline Settings

# %% [markdown]
# ### B1. Overview — Accessing Pipeline Settings
#
# Declarative Pipelines come with a variety of settings you can easily configure to customize how your pipeline behaves.
# <div style="text-align: center; margin-top: 20px;">
#   <img
#     src="https://files.training.databricks.com/binder/prod_main/build-data-pipelines-with-apache-spark-declarative-pipelines-en_us-3.2.1/images/20260902T093127Z/Build Data Pipelines with Apache Spark Declarative Pipelines/Includes/images/lecture_common_pipeline_settings/pipeline_settings.png" alt="Accessing Pipeline Seetings"
#     style="width: 1100px; max-width: 100%; height: auto;">
# </div>
#
# <div style="max-width:1100px; margin:0 auto; font-family:'Segoe UI',sans-serif;">
#
# <div style="display:flex; gap:16px; margin:20px 0; align-items:stretch;">
#
#   <!-- Left: Key message -->
#   <div style="flex:1; background:#1B5162; border-radius:12px; padding:24px 28px; color:white; display:flex; flex-direction:column; justify-content:center;">
#     <div style="font-size:13pt; font-weight:800; color:#FFAB00; margin-bottom:12px; text-transform:uppercase; letter-spacing:0.05em;">Edit Settings Directly in the Editor</div>
#     <div style="font-size:11.5pt; line-height:1.85; color:#c8dde4;">
#       With the new multi-file editor, accessing and editing pipeline settings is <strong style="color:white;">simple and intuitive</strong>.
#       <ul>
#       <li><strong style="color:white;">Quick Access Settings:</strong> Just click the small <strong style="color:#FFAB00;">gear</strong> icon in your editor window to quickly open the pipeline settings popup. No need to leave your development environment.
#       <br><br>
#       <li><strong style="color:white;">Seamless Configuration:</strong> From there, you can adjust key settings and options directly, helping you tailor your pipeline to your specific requirements without interrupting your workflow.
#       </ul>
#     </div>
#   </div>
#
#   <!-- Right: 3 core settings -->
#   <div style="width:320px; flex-shrink:0; display:flex; flex-direction:column; gap:10px;">
#   <div style="background:#F9F7F4; border:2px solid #EEEDE9; border-radius:10px; padding:14px 18px;">
#     <div style="font-size:9pt; font-weight:800; color:#5A6F77; text-transform:uppercase; letter-spacing:0.06em; margin-bottom:10px;">
#       3 Most Common Settings
#     </div>
#     <div style="display:flex; flex-direction:column; gap:10px;">
#       <!-- Compute -->
#       <div style="display:flex; align-items:center; gap:12px; background:white; border-radius:8px; padding:10px 12px; border-left:4px solid #2272B4;">
#         <img
#           src="https://files.training.databricks.com/binder/prod_main/build-data-pipelines-with-apache-spark-declarative-pipelines-en_us-3.2.1/images/20260902T093127Z/Build Data Pipelines with Apache Spark Declarative Pipelines/Includes/images/icons/compute_icon.png"
#           alt="Compute icon"
#           style="width:50px; height:50px; flex-shrink:0; background:transparent; mix-blend-mode:multiply; filter:contrast(1.05) brightness(1.02);">
#         <div>
#           <div style="font-weight:800; font-size:10pt; color:#1B3139;">Compute</div>
#           <div style="font-size:9pt; color:#5A6F77;">Resources &amp; environment</div>
#         </div>
#       </div>
#       <!-- Code Assets -->
#       <div style="display:flex; align-items:center; gap:12px; background:white; border-radius:8px; padding:10px 12px; border-left:4px solid #00A972;">
#         <img
#           src="https://files.training.databricks.com/binder/prod_main/build-data-pipelines-with-apache-spark-declarative-pipelines-en_us-3.2.1/images/20260902T093127Z/Build Data Pipelines with Apache Spark Declarative Pipelines/Includes/images/icons/code_assets_icon.png"
#           alt="Code assets icon"
#           style="width:50px; height:50px; flex-shrink:0; background:transparent; mix-blend-mode:multiply; filter:contrast(1.05) brightness(1.02);">
#         <div>
#           <div style="font-weight:800; font-size:10pt; color:#1B3139;">Code Assets</div>
#           <div style="font-size:9pt; color:#5A6F77;">Files and code modules</div>
#         </div>
#       </div>
#       <!-- Configuration -->
#       <div style="display:flex; align-items:center; gap:12px; background:white; border-radius:8px; padding:10px 12px; border-left:4px solid #FFAB00;">
#         <img
#           src="https://files.training.databricks.com/binder/prod_main/build-data-pipelines-with-apache-spark-declarative-pipelines-en_us-3.2.1/images/20260902T093127Z/Build Data Pipelines with Apache Spark Declarative Pipelines/Includes/images/icons/configurations_icon.png"
#           alt="Configuration icon"
#           style="width:50px; height:50px; flex-shrink:0; background:transparent; mix-blend-mode:multiply; filter:contrast(1.05) brightness(1.02);">
#         <div>
#           <div style="font-weight:800; font-size:10pt; color:#1B3139;">Configuration</div>
#           <div style="font-size:9pt; color:#5A6F77;">Pipeline parameters</div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
# </div>

# %% [markdown]
# We'll focus on these three settings now, and explore additional options during the upcoming demonstration.

# %% [markdown]
# ### B2. Compute
#
# Let’s begin with Compute, which lets you select the resources and environment where your pipeline will run.
#
# ##### Click each tab to explore the two compute options available for your pipeline.
#
# <div style="max-width:1000px; margin:0 auto; font-family:'Segoe UI',sans-serif;">
#
# <style>
# .compute-tab { padding:10px 20px; border:none; border-bottom:3px solid transparent; background:none; font-size:12pt; font-weight:700; color:#888; cursor:pointer; margin-bottom:-2px; transition:color 0.2s; }
# .compute-tab.active-tab { color:#2272B4; border-bottom:3px solid #2272B4; }
# .compute-panel { display:none; }
# .compute-panel.active-panel { display:block; }
# </style>
#
# <div style="border-bottom:2px solid #EEEDE9; margin-bottom:0; display:flex;">
#   <button class="compute-tab active-tab" onclick="showComputeTab(1)">Serverless (Recommended)</button>
#   <button class="compute-tab" onclick="showComputeTab(2)">Classic (Fixed Size)</button>
# </div>
# <br>
#
# <!-- TAB 1: Serverless -->
# <div class="compute-panel active-panel" id="compute-1">
#   <div style="background:#F9F7F4; border-radius:12px; overflow:hidden; border:2px solid #2272B4; box-shadow:0 3px 12px rgba(34,114,180,0.12);">
#     <div style="background:#2272B4; padding:14px 20px; color:white; font-weight:800; font-size:12pt; display:flex; align-items:center; gap:10px;">
#       Serverless Compute
#       <span style="background:#FFAB00; color:#1B3139; font-size:8.5pt; font-weight:800; padding:3px 10px; border-radius:999px; margin-left:8px;">DATABRICKS RECOMMENDED</span>
#     </div>
#     <div style="padding:20px 24px; display:grid; grid-template-columns:1fr 1fr; gap:14px;">
#       <div style="background:white; border-radius:8px; padding:14px 16px; border-left:4px solid #2272B4;">
#         <div style="font-weight:800; font-size:10.5pt; color:#1B3139; margin-bottom:6px;">Optimized Cost & Performance</div>
#         <div style="font-size:10pt; color:#5A6F77; line-height:1.7;">Serverless optimizes costs while maintaining strong performance.</div>
#       </div>
#       <div style="background:white; border-radius:8px; padding:14px 16px; border-left:4px solid #00A972;">
#         <div style="font-weight:800; font-size:10.5pt; color:#1B3139; margin-bottom:6px;">Focus on Code, Not Infrastructure</div>
#         <div style="font-size:10pt; color:#5A6F77; line-height:1.7;">It allows you to focus fully on your code without needing to manage or provision infrastructure.</div>
#       </div>
#       <div style="background:white; border-radius:8px; padding:14px 16px; border-left:4px solid #FFAB00;">
#         <div style="font-weight:800; font-size:10.5pt; color:#1B3139; margin-bottom:6px;">Incremental Refresh for MVs</div>
#         <div style="font-size:10pt; color:#5A6F77; line-height:1.7;">Support for incremental refresh of materialized views.</div>
#       </div>
#       <div style="background:white; border-radius:8px; padding:14px 16px; border-left:4px solid #FF5F46;">
#         <div style="font-weight:800; font-size:10.5pt; color:#1B3139; margin-bottom:6px;">Cost-Based Optimizer</div>
#         <div style="font-size:10pt; color:#5A6F77; line-height:1.7;">A cost-based optimizer that enables fast and efficient transformations of materialized views, improving pipeline efficiency and speed.</div>
#       </div>
#     </div>
#     <div style="margin:0 24px 20px 24px; background:white; border-left:4px solid #2272B4; border-radius:6px; padding:12px 16px; font-size:10pt; color:#1B3139; line-height:1.7;"><strong>Performance Optimized Setting:</strong> For time-sensitive Lakeflow Jobs, there's an optional <strong>Serverless Performance Optimized</strong> setting to boost responsiveness.
#     </div>
#   </div>
# </div>
#
# <!-- TAB 2: Classic -->
# <div class="compute-panel" id="compute-2">
#   <div style="background:#F9F7F4; border-radius:12px; overflow:hidden; border:2px solid #CD7F32; box-shadow:0 3px 12px rgba(48,63,71,0.12);">
#     <div style="background:#CD7F32; padding:14px 20px; color:white; font-weight:800; font-size:12pt;">
#       Classic Compute (Fixed Size)
#     </div>
#     <div style="padding:20px 24px; display:grid; grid-template-columns:1fr 1fr; gap:14px;">
#       <div style="background:white; border-radius:8px; padding:14px 16px; border-left:4px solid #303F47;">
#         <div style="font-weight:800; font-size:10.5pt; color:#1B3139; margin-bottom:6px;">Fixed-Size Clusters</div>
#         <div style="font-size:10pt; color:#5A6F77; line-height:1.7;">Classic Compute uses fixed-size clusters. Users need appropriate permissions to create compute resources for Declarative Pipelines.</div>
#       </div>
#       <div style="background:white; border-radius:8px; padding:14px 16px; border-left:4px solid #5A6F77;">
#         <div style="font-weight:800; font-size:10.5pt; color:#1B3139; margin-bottom:6px;">Permission & Policy Control</div>
#         <div style="font-size:10pt; color:#5A6F77; line-height:1.7;">Workspace administrators can set up cluster policies to control and provide access to compute resources for users.</div>
#       </div>
#       <div style="background:white; border-radius:8px; padding:14px 16px; border-left:4px solid #00A972; grid-column:1/-1;">
#         <div style="font-weight:800; font-size:10.5pt; color:#1B3139; margin-bottom:6px;">Enhanced Autoscaling — Enabled by Default</div>
#         <div style="font-size:10pt; color:#5A6F77; line-height:1.7;">Enhanced autoscaling is enabled by default for all new pipelines using Classic Compute. It automatically adjusts cluster size based on workload volume, optimizing resource utilization and helping control costs without manual intervention.</div>
#       </div>
#     </div>
#   </div>
# </div>
#
# <script>
# function showComputeTab(n) {
#   document.querySelectorAll('.compute-tab').forEach(function(t,i){ t.classList.toggle('active-tab', i===n-1); });
#   document.querySelectorAll('.compute-panel').forEach(function(p,i){ p.classList.toggle('active-panel', i===n-1); });
# }
# </script>
# </div>

# %% [markdown]
# #####Documentation
# - <a href="https://docs.databricks.com/aws/en/dlt/serverless-dlt#select-a-performance-mode" style="color: #1976d2; text-decoration: underline;">Serverless Performance Optimized</a>
# - <a href="https://docs.databricks.com/aws/en/dlt/serverless-dlt#serverless-pipeline-features" style="color: #1976d2; text-decoration: underline;">Serverless Pipeline Features</a>

# %% [markdown]
# ### B3. Code Assets
#
# Code Assets manage the files and code modules that make up your pipeline.
# .
#
# <div style="text-align: center; margin-top: 20px;">
#   <img
#     src="https://files.training.databricks.com/binder/prod_main/build-data-pipelines-with-apache-spark-declarative-pipelines-en_us-3.2.1/images/20260902T093127Z/Build Data Pipelines with Apache Spark Declarative Pipelines/Includes/images/lecture_common_pipeline_settings/code_assets.png"
#     alt="Code Assets Overview"
#     style="width: 1000px; max-width: 100%; height: auto;">
# </div>
#
# <div style="max-width:1000px; margin:0 auto; font-family:'Segoe UI',sans-serif;">
#
# <div style="display:grid; grid-template-columns:1fr 1fr; gap:16px; margin:20px 0;">
#
#   <!-- Pipeline Root Folder -->
#   <div style="border-radius:10px; overflow:hidden; border:2px solid #00A972; box-shadow:0 3px 12px rgba(0,169,114,0.12);">
#   <div style="background:#00A972; padding:12px 18px; color:white; font-weight:800; font-size:11pt;">
#       Pipeline Root Folder
#   </div>
#   <div style="background:#F9F7F4; padding:18px 20px;">
#       <div style="font-size:10.5pt; color:#1B3139; line-height:1.8;">
#         The <b>Pipeline Root Folder</b> is set to automatically and includes all relevant files within that folder for your pipeline project (unless otherwise specified by the user). <br><br>This can be a <b>Git folder</b>, enabling easy version control and collaboration.
#       </div>
#   </div>
#   </div>
#
#   <!-- Source Code Section -->
#   <div style="border-radius:10px; overflow:hidden; border:2px solid #2272B4; box-shadow:0 3px 12px rgba(34,114,180,0.12);">
#   <div style="background:#2272B4; padding:12px 18px; color:white; font-weight:800; font-size:11pt;">
#       Source Code Section
#   </div>
#   <div style="background:#F9F7F4; padding:18px 20px;">
#       <div style="font-size:10.5pt; color:#1B3139; line-height:1.8;">
#         The <strong>Source Code Section</strong> lets you specify which subfolders or individual files to include in your pipeline, typically sub folders and files within the root folder.
#         <br><br>
#         These can be:<br>
#         Python scripts | SQL files | Notebooks | etc.
#       </div>
#   </div>
#   </div>
#
# </div>
# </div>

# %% [markdown]
# #####EXPAND FOR ADDITIONAL NOTES
# <details>
# Code Assets setting controls what code files your pipeline uses during execution.<br>
# Together, these settings ensure your pipeline runs with the exact code it needs, organized and versioned as part of your project.
# </details>

# %% [markdown]
# ### B4. Configuration (Parameters)
#
# A pipeline's configuration is a map of **key-value pairs** that can be used to parameterize your code.
#
# <div style="max-width:1000px; margin:0 auto; font-family:'Segoe UI',sans-serif;">
# <div style="display:grid; grid-template-columns:1fr 1fr; gap:16px; margin:20px 0;">
#   <!-- Benefits -->
#   <div style="background:#F9F7F4; border-radius:12px; padding:20px 22px; border:2px solid #FFAB00; box-shadow:0 3px 12px rgba(255,171,0,0.12);">
#     <div style="font-weight:800; font-size:11pt; color:#1B3139; margin-bottom:14px; border-bottom:2px solid #EEEDE9; padding-bottom:10px;">
#       Why Use Configuration Parameters?
#     </div>
#     <div style="display:flex; flex-direction:column; gap:12px;">
#       <div style="display:flex; align-items:flex-start; gap:10px;">
#         <span style="background:#FFAB00; color:#1B3139; width:24px; height:24px; border-radius:50%; display:flex; align-items:center; justify-content:center; font-weight:800; font-size:11px; flex-shrink:0;">1</span>
#         <div style="font-size:10.5pt; color:#1B3139; line-height:1.7;">
#           <strong>Improves readability &amp; maintainability</strong> by centralizing key values.
#         </div>
#       </div>
#       <div style="display:flex; align-items:flex-start; gap:10px;">
#         <span style="background:#FFAB00; color:#1B3139; width:24px; height:24px; border-radius:50%; display:flex; align-items:center; justify-content:center; font-weight:800; font-size:11px; flex-shrink:0;">2</span>
#         <div style="font-size:10.5pt; color:#1B3139; line-height:1.7;">
#           <strong>Enables you to reuse</strong> common parameters across multiple pipeline files, avoiding hardcoding values.
#         </div>
#       </div>
#       <div style="display:flex; align-items:flex-start; gap:10px;">
#         <span style="background:#FFAB00; color:#1B3139; width:24px; height:24px; border-radius:50%; display:flex; align-items:center; justify-content:center; font-weight:800; font-size:11px; flex-shrink:0;">3</span>
#         <div style="font-size:10.5pt; color:#1B3139; line-height:1.7;">
#           <strong>Makes pipelines flexible</strong> and easier to update without changing code in multiple places.
#         </div>
#       </div>
#       <div style="font-size:10.5pt; color:#5A6F77; line-height:1.7; margin-bottom:12px;">
#     For example, you might have a parameter called <code>source</code> that points to a specific volume path.
#     <br><br>
#     In your SQL code, you can reference this parameter using the syntax <code style="background:#e8f0fe; padding:2px 6px; border-radius:4px; color:#1B3139;">&#36;{source}</code>, which dynamically inserts the value at runtime.
# </div>
# </div>
#
#   </div>
#   <!-- SQL Reference Syntax (updated) -->
#   <div style="background:#F9F7F4; border-radius:12px; padding:20px 22px; border:2px solid #2272B4; box-shadow:0 3px 12px rgba(34,114,180,0.12); overflow:hidden;">
#   <div style="font-weight:800; font-size:11pt; color:#1B3139; margin-bottom:14px; border-bottom:2px solid #EEEDE9; padding-bottom:10px;">
#       SQL Reference Syntax
#   </div>
#   <div style="max-width: 900px; margin: 0 auto; font-family: system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; position:relative; padding-left:22px;">
#       <svg xmlns="http://www.w3.org/2000/svg" width="20" height="218" viewBox="0 0 20 218" aria-hidden="true" style="position:absolute; left:0; top:70px; display:block; pointer-events:none;">
#         <path d="M 16 0 L 4 0 L 4 200 Q 4 212 14 212" fill="none" stroke="#FF5F46" stroke-width="2"/>
#         <polygon points="18,212 12,208 12,216" fill="#FF5F46"/>
#       </svg>
#       <div style="border:1px solid #D0D7DD; border-radius:8px; padding:12px 16px; margin-bottom:24px; background:#FFFFFF; overflow:hidden;">
#         <div style="font-size:13px; font-weight:600; color:#1B3139; margin-bottom:8px;">Configuration</div>
#         <div style="display:flex; align-items:center; gap:12px; margin-bottom:8px;">
#           <div style="flex:0 0 80px; font-size:11px; font-weight:600; color:#5A6F77;">Key*</div>
#           <div style="flex:1; font-size:11px; font-weight:600; color:#5A6F77; padding-left: 80px">Value</div>
#           <div style="flex:0 0 24px;"></div>
#         </div>
#         <div style="display:flex; align-items:center; gap:12px; min-width:0;">
#           <div style="flex:0 0 160px;">
#             <div style="border:1px solid #CDD4DB; border-radius:6px; padding:6px 8px; font-size:13px; color:#0B2026; background:#FDFDFD;">
#               source
#             </div>
#           </div>
#           <div style="flex:1; min-width:0; overflow:hidden;">
#             <div style="border:1px solid #CDD4DB; border-radius:6px; padding:6px 8px; font-size:13px; color:#0B2026; background:#FDFDFD; white-space:nowrap; overflow:hidden; text-overflow:ellipsis; max-width:100%; box-sizing:border-box;" title="/Volumes/dbacademy/ops/dbacademy_warehouse">
#               /Volumes/dbacademy/ops/dbacademy_warehouse
#             </div>
#           </div>
#           <div style="flex:0 0 24px; text-align:center; color:#9CA3AF; font-size:14px;">🗑</div>
#         </div>
#         <button style="margin-top:10px; padding:4px 10px; border-radius:4px; border:1px solid #D0D7DD; background:#F9F9FB; font-size:12px; color:#1B3139; cursor:default;">
#           Add parameter
#         </button>
#       </div>
#       <div style="border:1px solid #D0D7DD; border-radius:8px; padding:14px 16px; background:#FFFFFF;">
#         <div style="position:relative; margin:16px 0;">
#           <button type="button" id="b4-copy-btn" onclick="copyB4Sql()" style="position:absolute; top:8px; right:8px; padding:4px 12px; font-size:12px; background:#ddd; color:#333; border:1px solid #ccc; border-radius:4px; cursor:pointer; z-index:10;">Copy</button>
#           <pre style="background:#f8f8f8; border-radius:8px; padding:16px; padding-top:40px; overflow-x:auto; margin:0; border:1px solid #e0e0e0;"><code id="b4-sql-code" style="font-family:Consolas,Monaco,monospace; font-size:14px; color:#1B3139; white-space:pre;">CREATE STREAMING TABLE bronze
# SELECT *
# FROM STREAM read_files(
#   "<span style='background:#e8f0fe; padding:0 2px; border-radius:3px;'>&#36;{source}</span>/orders",
#   format =&gt; 'JSON'
# );</code></pre>
#         </div>
#       </div>
#       <script>
#       if (typeof copyB4Sql !== 'function') {
#         function copyB4Sql() {
#           var btn = document.getElementById('b4-copy-btn');
#           var sql = 'CREATE STREAMING TABLE bronze\nSELECT *\nFROM STREAM read_files(\n  "' + '$' + '{source}/orders",\n  format => \'JSON\'\n);';
#           function showCopied() {
#             btn.textContent = '✓ Copied!';
#             setTimeout(function() { btn.textContent = 'Copy'; }, 2000);
#           }
#           function fallback() {
#             var t = document.createElement('textarea');
#             t.value = sql;
#             document.body.appendChild(t);
#             t.select();
#             document.execCommand('copy');
#             document.body.removeChild(t);
#             showCopied();
#           }
#           if (navigator.clipboard && navigator.clipboard.writeText) {
#             navigator.clipboard.writeText(sql).then(showCopied).catch(fallback);
#           } else {
#             fallback();
#           }
#         }
#       }
#       </script>
#   </div>
#   </div>
# </div>
# </div>

# %% [markdown]
# ### B5. Additional Pipeline Settings
#
# Beyond the core settings we've discussed, there are several other pipeline settings you’ll encounter throughout the course.
#
# #####Place cursor over the highlighted headings to know more about additional pipeline settings.
# <br>
#
# <div style="max-width: 700px; margin: 0 auto; font-family: system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#
# <style>
#   .pipeline-hotspot-wrap {
#     position: relative;
#     display: inline-block;
#     max-width: 100%;
#   }
#   .pipeline-hotspot-img {
#     width: 100%;
#     height: auto;
#     border-radius: 4px;
#     border: 1px solid #d0d7dd;
#     display: block;
#   }
#
#   .hs-box {
#     position: absolute;
#     border: 2px solid rgba(255,95,70,0.9);
#     background: rgba(255,95,70,0.06);
#     border-radius: 6px;
#     box-sizing: border-box;
#     cursor: pointer;
#   }
#   .hs-label {
#     position: absolute;
#     top: -11px;
#     left: -11px;
#     width: 22px;
#     height: 22px;
#     border-radius: 999px;
#     background: #FF5F46;
#     color: #ffffff;
#     font-size: 16px;
#     font-weight: 800;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     box-shadow: 0 2px 6px rgba(15,23,42,0.35);
#   }
#
#   .hs-tooltip {
#     position: absolute;
#     left: 100%;
#     top: 0;
#     margin-left: 10px;
#     min-width: 260px;
#     max-width: 320px;
#     background: #F9F7F4;
#     border-radius: 8px;
#     border: 1px solid #D0D7DD;
#     padding: 10px 12px;
#     font-size: 16px;
#     color: #0B2026;
#     box-shadow: 0 3px 10px rgba(15,23,42,0.12);
#     line-height: 1.6;
#     display: none;
#     z-index: 5;
#   }
#   .hs-tooltip-title {
#     font-weight: 800;
#     margin-bottom: 2px;
#     color: #1B3139;
#   }
#   .hs-box:hover .hs-tooltip {
#     display: block;
#   }
#
#   /* Approximate highlight positions (tuned for this screenshot) */
#   .hs-1 { top: 2%;  left: 4%;  width: 30%; height: 5%; }   /* Pipeline settings */
#   .hs-2 { top: 26%; left: 4%;  width: 19%; height: 5%; }   /* Code assets */
#   .hs-3 { top: 43%; left: 4%;  width: 43%; height: 5%; }  /* Default location */
#   .hs-4 { top: 59.5%; left: 4%;  width: 15%; height: 5%; }   /* Compute */
#   .hs-5 { top: 70.5%; left: 4%;  width: 20%; height: 5%; }  /* Configuration */
#   .hs-6 { top: 86%; left: 4%;  width: 8%; height: 4%; }   /* Tags */
#
#   @media (max-width: 800px) {
#     .hs-tooltip {
#       left: 0;
#       top: 100%;
#       margin-left: 0;
#       margin-top: 6px;
#     }
#   }
# </style>
#
# <div class="pipeline-hotspot-wrap">
#   <img
#     src="https://files.training.databricks.com/binder/prod_main/build-data-pipelines-with-apache-spark-declarative-pipelines-en_us-3.2.1/images/20260902T093127Z/Build Data Pipelines with Apache Spark Declarative Pipelines/Includes/images/lecture_common_pipeline_settings/pipeline_settings_details.png"
#     alt="Pipeline settings panel"
#     class="pipeline-hotspot-img">
#   <!-- 1. Pipeline settings -->
#   <div class="hs-box hs-1">
#     <div class="hs-label">1</div>
#     <div class="hs-tooltip">
#       <div class="hs-tooltip-title">Pipeline Settings</div>
#       <div>General pipeline behavior and metadata.</div>
#     </div>
#   </div>
#   <!-- 2. Code assets -->
#   <div class="hs-box hs-2">
#     <div class="hs-label">2</div>
#     <div class="hs-tooltip">
#       <div class="hs-tooltip-title">Code Assets</div>
#       <div>Managing your pipeline code files.</div>
#     </div>
#   </div>
#   <!-- 3. Default location for data assets -->
#   <div class="hs-box hs-3">
#     <div class="hs-label">3</div>
#     <div class="hs-tooltip">
#       <div class="hs-tooltip-title">Default Location for Data Assets</div>
#       <div>Setting where data is stored by default.</div>
#     </div>
#   </div>
#   <!-- 4. Compute -->
#   <div class="hs-box hs-4">
#     <div class="hs-label">4</div>
#     <div class="hs-tooltip">
#       <div class="hs-tooltip-title">Compute</div>
#       <div>Choosing your execution environment.</div>
#     </div>
#   </div>
#   <!-- 5. Configuration (+ environment dependencies) -->
#   <div class="hs-box hs-5">
#     <div class="hs-label">5</div>
#     <div class="hs-tooltip">
#       <div class="hs-tooltip-title">Configuration</div>
#       <div>Parameterizing your pipeline code.</div>
#       <div style="margin-top:4px;">
#         <strong>Environment dependencies</strong> &mdash; A dependency is a line in a pip requirements file.
#       </div>
#     </div>
#   </div>
#   <!-- 6. Tags -->
#   <div class="hs-box hs-6">
#     <div class="hs-label">6</div>
#     <div class="hs-tooltip">
#       <div class="hs-tooltip-title">Tags</div>
#       <div>Organizing and categorizing pipelines for easy management.</div>
#     </div>
#   </div>
# </div>
# </div>

# %% [markdown]
# #####EXPAND FOR ADDITIONAL NOTES
# <details>
#
# Other additional features include
# - Budget - Defining cost controls and limits
# - Advanced Settings - Additional options for fine-tuning your pipeline
#
# We’ll explore these in more detail with hands-on demonstrations to help you get the most out of Spark Declarative Pipelines.
# </details>

# %% [markdown]
# ## C. Conclusion
#
# In this lecture, you learned how dataset types, the multi-file editor, and common pipeline settings work together to support reliable Apache Spark™ Declarative Pipeline development:
#
# 1. **Streaming tables, materialized views, and views** support different data processing patterns, from incremental ingestion to refreshed aggregations and on-demand query execution.
# 2. **Declarative SQL syntax** provides a consistent way to create pipeline datasets while Databricks automatically manages dependencies through the Declarative Pipeline Graph.
# 3. **The multi-file editor** simplifies pipeline development by combining pipeline assets, modular code editing, DAG visualization, data previews, execution insights, and validation tools in one environment.
# 4. **Pipeline settings** let you customize compute, code assets, configuration parameters, and additional options to make pipelines easier to manage, reuse, and scale.

# %% [markdown]
# &copy; <span id="dbx-year"></span> Databricks, Inc. All rights reserved.
# Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/>
# <a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> |
# <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> |
# <a href="https://help.databricks.com/" target="_blank">Support</a>
# <script>
#   document.getElementById("dbx-year").textContent = new Date().getFullYear();
# </script>
